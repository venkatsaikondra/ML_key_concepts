# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
 import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

# %%
x_train.shape
# Out:
# (90, 2)

# %%
x_test.shape
# Out:
# (10, 2)

# %%
y_train.shape
# Out:
# (90,)

# %%
y_test.shape
# Out:
# (10,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-1.05046585,  0.42139055],
#        [-0.0124941 , -0.52129959],
#        [ 0.85248235,  1.24322298],
#        [ 0.33349648, -0.182898  ],
#        [-1.05046585, -0.27958417],
#        [-0.1854894 ,  1.0256791 ],
#        [-0.9639682 , -1.51233282],
#        [ 0.07400354, -0.49712805],
#        [-0.9639682 ,  0.25218976],
#        [-1.48295408,  1.84751154],
#        [-1.05046585,  1.09819373],
#        [ 1.97695174,  1.07402219],
#        [-0.0124941 , -1.89907749],
#        [-0.70447527,  0.20384667],
#        [ 1.54446351, -0.23124109],
#        [ 0.76598471, -0.66632884],
#        [-2.17493524,  2.64517243],
#        [ 0.67948706, -0.27958417],
#        [-0.0124941 ,  0.01047433],
#        [-1.74244701, -0.56964268],
#        [ 0.33349648,  0.42139055],
#        [ 0.24699883,  0.1071605 ],
#        [ 0.07400354, -1.02890198],
#        [ 0.07400354,  0.78396368],
#        [ 0.24699883, -0.49712805],
#        [ 1.11197529, -0.90804427],
#        [-0.70447527,  2.42762855],
#        [-0.70447527, -0.8113581 ],
#        [ 0.41999412, -0.8113581 ],
#        [ 1.11197529, -0.182898  ],
#        [-1.82894466, -0.3520988 ],
#        [ 1.80395645,  0.61476289],
#        [-0.87747056, -1.46398973],
#        [-0.27198704,  1.09819373],
#        [ 1.11197529,  0.32470438],
#        [-0.9639682 ,  0.66310597],
#        [-1.39645643, -1.97159212],
#        [ 0.50649177, -0.08621183],
#        [-0.9639682 ,  1.75082537],
#        [ 0.85248235,  1.82333999],
#        [ 1.19847293,  0.20384667],
#        [-0.79097291,  0.1071605 ],
#        [-0.87747056, -0.13455492],
#        [ 0.59298941,  1.41242378],
#        [ 0.85248235, -1.43981819],
#        [ 0.93898   ,  0.66310597],
#        [-0.61797762, -0.06204029],
#        [ 1.37146822, -0.83552964],
#        [-1.1369635 , -1.7298767 ],
#        [ 0.67948706,  0.42139055],
#        [-0.27198704,  0.20384667],
#        [-0.70447527, -0.32792725],
#        [ 1.28497058,  0.15550359],
#        [-2.34793053,  1.43659532],
#        [-0.27198704,  0.39721901],
#        [-0.87747056, -0.78718655],
#        [ 0.76598471,  0.34887592],
#        [-0.70447527,  0.90482139],
#        [ 0.93898   , -1.82656287],
#        [ 0.41999412, -2.09244983],
#        [-0.53147998, -0.40044188],
#        [-0.53147998, -0.23124109],
#        [-0.1854894 ,  0.44556209],
#        [-0.79097291, -1.39147511],
#        [ 0.67948706, -0.8113581 ],
#        [-0.9639682 , -0.08621183],
#        [-1.74244701, -1.17393123],
#        [ 0.07400354,  0.20384667],
#        [ 1.28497058,  0.83230677],
#        [-0.0124941 ,  0.61476289],
#        [ 1.11197529, -1.77821978],
#        [-1.22346114,  0.54224826],
#        [-0.9639682 ,  0.75979214],
#        [ 1.80395645,  1.0256791 ],
#        [ 1.71745881, -1.07724506],
#        [ 0.50649177,  0.34887592],
#        [-0.79097291,  1.26739452],
#        [-1.39645643,  0.61476289],
#        [ 2.14994703, -0.08621183],
#        [-0.53147998,  0.2763613 ],
#        [ 0.07400354, -1.41564665],
#        [ 0.59298941,  0.7356206 ],
#        [ 0.85248235, -0.27958417],
#        [ 0.41999412,  0.88064985],
#        [ 1.28497058, -1.51233282],
#        [ 0.41999412,  0.15550359],
#        [-0.0124941 , -1.39147511],
#        [ 0.67948706, -0.01369721],
#        [ 0.85248235,  0.37304747],
#        [-0.27198704,  0.46973364]])

# %%
x_test=scaler.fit_transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 23    0
# 70    1
# 12    0
# 99    1
# 24    0
# 30    1
# 46    0
# 34    0
# 1     0
# 60    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle
pickle.dump(clf,open('model.pkl','wb'))
