# %%
from sklearn.datasets import fetch_california_housing

data = fetch_california_housing()

X = data.data
y = data.target

# %%
X.shape
# Out:
# (20640, 8)

# %%
y.shape
# Out:
# (20640,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
import numpy as np

lr = LinearRegression()
dt = DecisionTreeRegressor()
svr = SVR()

estimators = [('lr', lr), ('dt', dt), ('svr', svr)]

for estimator in estimators:
    scores = cross_val_score(estimator[1], X, y, scoring='r2', cv=10)
    print(estimator[0], np.round(np.mean(scores), 2))
# Out:
# lr 0.51
# dt 0.24
# svr -0.25

# %%
from sklearn.ensemble import VotingRegressor
vr=VotingRegressor(estimators)
scores = cross_val_score(vr, X, y, scoring='r2', cv=10)
print("Voting Regressor:", np.round(np.mean(scores), 2))
# Out:
# Voting Regressor: 0.48

# %%
for i in range(1,4):
    for j in range(1,4):
        for k in range(1,4):
            vr=VotingRegressor(estimators,weights=[i,j,k])
            scores = cross_val_score(vr, X, y, scoring='r2', cv=10)
            print("For i={},j={},k={}".format(i,j,k), np.round(np.mean(scores), 2))
# Out:
# For i=1,j=1,k=1 0.47
# For i=1,j=1,k=2 0.37
# For i=1,j=1,k=3 0.28
# For i=1,j=2,k=1 0.48
# For i=1,j=2,k=2 0.42
# For i=1,j=2,k=3 0.36
# For i=1,j=3,k=1 0.46
# For i=1,j=3,k=2 0.44
# For i=1,j=3,k=3 0.4
# For i=2,j=1,k=1 0.52
# For i=2,j=1,k=2 0.44
# For i=2,j=1,k=3 0.37
# For i=2,j=2,k=1 0.52
# For i=2,j=2,k=2 0.48
# For i=2,j=2,k=3 0.42
# For i=2,j=3,k=1 0.51
# For i=2,j=3,k=2 0.48
# For i=2,j=3,k=3 0.44
# For i=3,j=1,k=1 0.53
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 5
#       3 for k in range(1,4):
#       4     vr=VotingRegressor(estimators,weights=[i,j,k])
# ----> 5     scores = cross_val_score(vr, X, y, scoring='r2', cv=10)
#       6     print("For i={},j={},k={}".format(i,j,k), np.round(np.mean(scores), 2))
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/model_selection/_validation.py:651, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     648 # To ensure multimetric format is not supported
#     649 scorer = check_scoring(estimator, scoring=scoring)
# --> 651 cv_results = cross_validate(
#     652     estimator=estimator,
#     653     X=X,
#     654     y=y,
#     655     groups=groups,
#     656     scoring={"score": scorer},
#     657     cv=cv,
#     658     n_jobs=n_jobs,
#     659     verbose=verbose,
#     660     params=params,
#     661     pre_dispatch=pre_dispatch,
#     662     error_score=error_score,
#     663 )
#     664 return cv_results["test_score"]
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/model_selection/_validation.py:373, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     370 # We clone the estimator to make sure that all the folds are
#     371 # independent, and that it is pickle-able.
#     372 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 373 results = parallel(
#     374     delayed(_fit_and_score)(
#     375         clone(estimator),
#     376         X,
#     377         y,
#     378         scorer=scorers,
#     379         train=train,
#     380         test=test,
#     381         verbose=verbose,
#     382         parameters=None,
#     383         fit_params=routed_params.estimator.fit,
#     384         score_params=routed_params.scorer.score,
#     385         return_train_score=return_train_score,
#     386         return_times=True,
#     387         return_estimator=return_estimator,
#     388         error_score=error_score,
#     389     )
#     390     for train, test in indices
#     391 )
#     393 _warn_or_raise_about_fit_failures(results, error_score)
#     395 # For callable scoring, the return type is only know after calling. If the
#     396 # return type is a dictionary, the error scores can now be inserted with
#     397 # the correct key.
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/utils/parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/utils/parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/model_selection/_validation.py:833, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     831         estimator.fit(X_train, **fit_params)
#     832     else:
# --> 833         estimator.fit(X_train, y_train, **fit_params)
#     835 except Exception:
#     836     # Note fit time as time until error
#     837     fit_time = time.time() - start_time
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/ensemble/_voting.py:678, in VotingRegressor.fit(self, X, y, **fit_params)
#     674 _raise_for_params(fit_params, self, "fit", allow=["sample_weight"])
#     676 y = column_or_1d(y, warn=True)
# --> 678 return super().fit(X, y, **fit_params)
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/ensemble/_voting.py:99, in _BaseVoting.fit(self, X, y, **fit_params)
#      94         if "sample_weight" in fit_params:
#      95             routed_params[name].fit["sample_weight"] = fit_params[
#      96                 "sample_weight"
#      97             ]
# ---> 99 self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#     100     delayed(_fit_single_estimator)(
#     101         clone(clf),
#     102         X,
#     103         y,
#     104         fit_params=routed_params[name]["fit"],
#     105         message_clsname="Voting",
#     106         message=self._log_message(name, idx + 1, len(clfs)),
#     107     )
#     108     for idx, (name, clf) in enumerate(zip(names, clfs))
#     109     if clf != "drop"
#     110 )
#     112 self.named_estimators_ = Bunch()
#     114 # Uses 'drop' as placeholder for dropped estimators
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/utils/parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/utils/parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/ensemble/_base.py:45, in _fit_single_estimator(estimator, X, y, fit_params, message_clsname, message)
#      43 else:
#      44     with _print_elapsed_time(message_clsname, message):
# ---> 45         estimator.fit(X, y, **fit_params)
#      46 return estimator
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/svm/_base.py:266, in BaseLibSVM.fit(self, X, y, sample_weight)
#     263     print("[LibSVM]", end="")
#     265 seed = rnd.randint(np.iinfo("i").max)
# --> 266 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     267 # see comment on the other call to np.iinfo in this file
#     269 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/svm/_base.py:344, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     330 libsvm.set_verbosity_wrap(self.verbose)
#     332 # we don't pass **self.get_params() to allow subclasses to
#     333 # add other parameters to __init__
#     334 (
#     335     self.support_,
#     336     self.support_vectors_,
#     337     self._n_support,
#     338     self.dual_coef_,
#     339     self.intercept_,
#     340     self._probA,
#     341     self._probB,
#     342     self.fit_status_,
#     343     self._num_iter,
# --> 344 ) = libsvm.fit(
#     345     X,
#     346     y,
#     347     svm_type=solver_type,
#     348     sample_weight=sample_weight,
#     349     class_weight=getattr(self, "class_weight_", np.empty(0)),
#     350     kernel=kernel,
#     351     C=self.C,
#     352     nu=self.nu,
#     353     probability=self.probability,
#     354     degree=self.degree,
#     355     shrinking=self.shrinking,
#     356     tol=self.tol,
#     357     cache_size=self.cache_size,
#     358     coef0=self.coef0,
#     359     gamma=self._gamma,
#     360     epsilon=self.epsilon,
#     361     max_iter=self.max_iter,
#     362     random_seed=random_seed,
#     363 )
#     365 self._warn_from_fit_status()
#
# File ~/PycharmProjects/100_days_ml/.venv/lib/python3.13/site-packages/sklearn/svm/_libsvm.pyx:263, in sklearn.svm._libsvm.fit()
#
# KeyboardInterrupt:
